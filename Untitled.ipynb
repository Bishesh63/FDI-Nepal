# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('mainfile1.csv')

# %%
df
# Out:
#           Country                  Category  ForeignInvestment  Date  \
# 0           China  Agriculture and Forestry              12.00  2005
# 1           China              Construction              53.88  2005
# 2           China             Manufacturing               2.95  2005
# 3           India             Manufacturing               5.00  2005
# 4     Netherlands             Manufacturing              15.30  2005
# ...           ...                       ...                ...   ...
# 3759        China                   Tourism             250.00  2020
# 3760        India                   Tourism              50.00  2020
# 3761        India                   Tourism              50.00  2020
# 3762        India                   Tourism              50.00  2020
# 3763        China             Manufacturing             125.00  2020
#
#      FinancialYear
# 0        2004-2005
# 1        2004-2005
# 2        2004-2005
# 3        2004-2005
# 4        2004-2005
# ...

# %%
df.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['ForeignInvestment'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df1 = df.groupby(['Country'])['ForeignInvestment'].sum()

# %%
df1.plot(kind='bar', title='Foreign Investment by country', ylabel='Investment',
         xlabel='Country', figsize=(25, 8))
# Out:
# <AxesSubplot:title={'center':'Foreign Investment by country'}, xlabel='Country', ylabel='Investment'>

# %%
df1
# Out:
# Country
# Afganistan      5.00
# Argentina      18.01
# Australia     925.56
# Austria        16.00
# Azerbaijan     36.10
#                ...
# Uae            34.00
# Ukraine       151.70
# Uzbekistan    165.00
# Vietnam       111.00
# Yemen         105.00
# Name: ForeignInvestment, Length: 88, dtype: float64

# %%
df2 = df.groupby(['Category'])['ForeignInvestment'].sum()

# %%
df2.plot(kind='bar', title='Foreign Investment by country', ylabel='Investment',
         xlabel='Category', figsize=(9, 5))
# Out:
# <AxesSubplot:title={'center':'Foreign Investment by country'}, xlabel='Category', ylabel='Investment'>

# %%
df2
# Out:
# Category
# Agriculture and Forestry                                 7517.825400
# Construction                                             6679.430000
# Energy                                                 235241.290000
# Information, Technology and Transmission Technology     11968.371800
# Manufacturing                                          100878.571913
# Mines and Minerals                                      10027.400000
# Service                                                 69427.600480
# Tourism                                                 58213.450680
# Name: ForeignInvestment, dtype: float64

# %%
df.groupby('Category')['Category'].count().plot.pie(autopct='%.2f',figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='Category'>

# %%
df.plot(style='k.')
plt.show()

# %%
df
# Out:
#           Country                  Category  ForeignInvestment  Date  \
# 0           China  Agriculture and Forestry              12.00  2005
# 1           China              Construction              53.88  2005
# 2           China             Manufacturing               2.95  2005
# 3           India             Manufacturing               5.00  2005
# 4     Netherlands             Manufacturing              15.30  2005
# ...           ...                       ...                ...   ...
# 3759        China                   Tourism             250.00  2020
# 3760        India                   Tourism              50.00  2020
# 3761        India                   Tourism              50.00  2020
# 3762        India                   Tourism              50.00  2020
# 3763        China             Manufacturing             125.00  2020
#
#      FinancialYear
# 0        2004-2005
# 1        2004-2005
# 2        2004-2005
# 3        2004-2005
# 4        2004-2005
# ...

# %%
# Out:
# PeriodIndex(['1992', '1993', '1994', '1995'], dtype='period[A-DEC]', freq='A-DEC')

# %%
df
# Out:
#           Country                  Category  ForeignInvestment  Date  \
# 0           China  Agriculture and Forestry              12.00  2005
# 1           China              Construction              53.88  2005
# 2           China             Manufacturing               2.95  2005
# 3           India             Manufacturing               5.00  2005
# 4     Netherlands             Manufacturing              15.30  2005
# ...           ...                       ...                ...   ...
# 3759        China                   Tourism             250.00  2020
# 3760        India                   Tourism              50.00  2020
# 3761        India                   Tourism              50.00  2020
# 3762        India                   Tourism              50.00  2020
# 3763        China             Manufacturing             125.00  2020
#
#      FinancialYear
# 0        2004-2005
# 1        2004-2005
# 2        2004-2005
# 3        2004-2005
# 4        2004-2005
# ...

# %%
df.Date = pd.to_datetime(df.Date, format='%Y')

# %%
df.dtypes
# Out:
# Country                      object
# Category                     object
# ForeignInvestment           float64
# Date                 datetime64[ns]
# FinancialYear                object
# dtype: object

# %%
df
# Out:
#           Country                  Category  ForeignInvestment       Date  \
# 0           China  Agriculture and Forestry              12.00 2005-01-01
# 1           China              Construction              53.88 2005-01-01
# 2           China             Manufacturing               2.95 2005-01-01
# 3           India             Manufacturing               5.00 2005-01-01
# 4     Netherlands             Manufacturing              15.30 2005-01-01
# ...           ...                       ...                ...        ...
# 3759        China                   Tourism             250.00 2020-01-01
# 3760        India                   Tourism              50.00 2020-01-01
# 3761        India                   Tourism              50.00 2020-01-01
# 3762        India                   Tourism              50.00 2020-01-01
# 3763        China             Manufacturing             125.00 2020-01-01
#
#      FinancialYear
# 0        2004-2005
# 1        2004-2005
# ...

# %%
sns.set(rc={'figure.figsize':(20, 4)})

# %%
df['ForeignInvestment'].plot(linewidth=0.5);

# %%
df1 = df.groupby(['Country','Date'])['ForeignInvestment'].sum()
df2 = df.groupby(['Category','Date'])['ForeignInvestment'].sum()

# %%
df1
# Out:
# Country     Date
# Afganistan  2013-01-01      5.00
# Argentina   2013-01-01      8.00
#             2014-01-01     10.01
# Australia   2007-01-01     12.20
#             2008-01-01     66.33
#                            ...
# Uzbekistan  2017-01-01     30.00
# Vietnam     2010-01-01     96.00
#             2018-01-01     15.00
# Yemen       2013-01-01      5.00
#             2016-01-01    100.00
# Name: ForeignInvestment, Length: 510, dtype: float64

# %%
df2
# Out:
# Category                  Date
# Agriculture and Forestry  2005-01-01       12.00000
#                           2008-01-01       80.70000
#                           2009-01-01      596.70000
#                           2010-01-01      100.00000
#                           2011-01-01      473.40000
#                                            ...
# Tourism                   2016-01-01     1891.14000
#                           2017-01-01     6008.48640
#                           2018-01-01     4194.24000
#                           2019-01-01    10796.19428
#                           2020-01-01    11624.00000
# Name: ForeignInvestment, Length: 96, dtype: float64

# %%
#df['Category_Code'].value_counts()

# %%
df.ForeignInvestment.describe()
# Out:
# count     3764.000000
# mean       133.476639
# std       1212.090239
# min          0.000000
# 25%          5.000000
# 50%         12.000000
# 75%         35.000000
# max      39950.500000
# Name: ForeignInvestment, dtype: float64

# %%
sns.set_style('darkgrid')
sns.countplot(x='Category', hue ='Category', data=df)
# Out:
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
df['Category_Code'] = pd.factorize(df['Category'])[0] + 1
df.dtypes
# Out:
# Country                      object
# Category                     object
# ForeignInvestment           float64
# Date                 datetime64[ns]
# FinancialYear                object
# Category_Code                 int64
# dtype: object

# %%
sns.set_theme(style="dark")
g = sns.relplot(
    data=df,
    x="Category_Code", y="ForeignInvestment", col="Date", hue="Date",
    kind="line", palette="crest", linewidth=4, zorder=5,
    col_wrap=3, height=2, aspect=1.5, legend=False,
)

# Iterate over each subplot to customize further
for year, ax in g.axes_dict.items():

    # Add the title as an annotation within the plot
    ax.text(.8, .85, year, transform=ax.transAxes, fontweight="bold")

    # Plot every year's time series in the background
    sns.lineplot(
        data=df, x="Category_Code", y="ForeignInvestment", units="Date",
        estimator=None, color=".7", linewidth=1, ax=ax,
    )

# Reduce the frequency of the x axis ticks
ax.set_xticks(ax.get_xticks()[::2])

# Tweak the supporting aspects of the plot
g.set_titles("")
g.set_axis_labels("", "ForeignInvestment")
g.tight_layout()

# %%
sns.set(rc={'figure.figsize':(20,8.27)})

# %%
fig, ax = plt.subplots(figsize=(20, 20))
sns.lineplot(x="Date", y="ForeignInvestment", data=df, hue="Category_Code", palette="Dark2", ax=ax)
ax.xaxis.set_major_locator(plt.MaxNLocator(20))

# %%
sns.countplot(x='Date', hue='Category', data=df, palette='Set1')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='count'>

# %%
sns.boxplot(x='Category_Code',y='ForeignInvestment',data=df)
# Out:
# <AxesSubplot:xlabel='Category_Code', ylabel='ForeignInvestment'>
